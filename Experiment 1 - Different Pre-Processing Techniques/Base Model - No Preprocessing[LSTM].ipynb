# %% [markdown]
# **This experiment investigates the performance and effectiveness of the base architechture - BiLSTM**

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1: Import Dependencies

# %%
# !pip install tensorflow
# !pip install livelossplot
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(42)
plt.style.use("ggplot")
import tensorflow as tf

# %% [markdown]
# Import relevant functions from the utilities.py file

# %%
import sys
sys.path.append('/content/drive/MyDrive/Natural_Language_Processing')

# Reload incase of any changes to the functions
from utilities import SentanceGetter, preprocess_data, evaluate_model, show_random_example

# %% [markdown]
# ### 2: Dataset Loading and Preparation

# %% [markdown]
# TAGS:
# - B-AC signifies that token is an abbreviation/acronym
# - B-LF signifies that a long form ‘begins’ with this token.
# - I-LF label signifies that the token is ‘inside’ of a long form.
# - B-O (or ‘O’) indicate other tokens which are neither abbreviations nor long forms.
# - PAD - added later, represents padding.

# %%
# Load the dataset
dataset_path = '/content/drive/MyDrive/Natural_Language_Processing/combined_train_data.csv'
data = pd.read_csv(dataset_path)

# Display the first few rows of the dataset
print(data.head())
# Out:
#    index   Sentence #        Word    POS   Tag
# 0      0  Sentence: 1         For    ADP   B-O
# 1      0          NaN        this    DET   B-O
# 2      0          NaN     purpose   NOUN   B-O
# 3      0          NaN         the    DET   B-O
# 4      0          NaN  Gothenburg  PROPN  B-LF

# %%
#Looking for null values
print(data.isnull().sum())
# Out:
# index             0
# Sentence #    48649
# Word              5
# POS               0
# Tag               0
# dtype: int64

# %% [markdown]
# Data For the Base Model

# %%
#Filling Null Values (if any)
train_data = data.fillna(method='ffill')
train_data.head()
# Out:
#    index   Sentence #        Word    POS   Tag
# 0      0  Sentence: 1         For    ADP   B-O
# 1      0  Sentence: 1        this    DET   B-O
# 2      0  Sentence: 1     purpose   NOUN   B-O
# 3      0  Sentence: 1         the    DET   B-O
# 4      0  Sentence: 1  Gothenburg  PROPN  B-LF

# %%
print("Unique Words in corpus:",data['Word'].nunique())
print("Unique Tag in corpus:",data['Tag'].nunique())
# Out:
# Unique Words in corpus: 10587
# Unique Tag in corpus: 4

# %%
# Count of each tag
tag_counts = train_data['Tag'].value_counts()
print(tag_counts)
# Out:
# Tag
# B-O     41524
# I-LF     3846
# B-AC     2869
# B-LF     1761
# Name: count, dtype: int64

# %% [markdown]
# ENDPAD (for padding) needs to be added to the list of unique words as it will be the token representation of padding.

# %%
#Storing unique words and tags as a list
words = list(set(train_data['Word'].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(train_data['Tag'].values))
num_tags = len(tags)

# %% [markdown]
# PAD = the padding class

# %%
tags = ['PAD','B-AC', 'I-LF', 'B-O', 'B-LF']

# %%
num_words, num_tags
# Out:
# (10588, 4)

# %% [markdown]
# ### 3: Retrieve Sentences/Token sequences

# %%
getter = SentanceGetter(train_data)
sentances = getter.sentances

# %% [markdown]
# Confirm data appears in the correct format

# %%
sentances[0][0:15]
# Out:
# [('For', 'ADP', 'B-O'),
#  ('this', 'DET', 'B-O'),
#  ('purpose', 'NOUN', 'B-O'),
#  ('the', 'DET', 'B-O'),
#  ('Gothenburg', 'PROPN', 'B-LF'),
#  ('Young', 'PROPN', 'I-LF'),
#  ('Persons', 'PROPN', 'I-LF'),
#  ('Empowerment', 'PROPN', 'I-LF'),
#  ('Scale', 'PROPN', 'I-LF'),
#  ('(', 'PUNCT', 'B-O'),
#  ('GYPES', 'PROPN', 'B-AC'),
#  (')', 'PUNCT', 'B-O'),
#  ('was', 'AUX', 'B-O'),
#  ('developed', 'VERB', 'B-O'),
#  ('.', 'PUNCT', 'B-O')]

# %% [markdown]
# ### 4: Mappings between Sentences and NER Tags

# %%
word2idx =  {w : i+1 for i,w in enumerate(words)}
tag2idx = {
    "PAD": 0,  # Padding value
    "B-O": 1,  # Valid class
    "B-AC": 2,  # Valid class
    "B-LF": 3,  # Valid class
    "I-LF": 4  # Valid class
}

# %% [markdown]
# ### 5: Padding Input Sentences and Creating Train/Test Splits

# %%
num_tags = len(tag2idx)

# %%
plt.hist([len(s) for s in sentances], bins=100)
plt.show()

# %% [markdown]
# Based on the histogram, a maximum sequence length of 50 was chosen as most entries fall within that threshold.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

max_len = 50
padding_value = word2idx["ENDPAD"]

X, y = preprocess_data(sentances, word2idx, tag2idx, max_len, num_words, num_tags)

# %%
word2idx["ENDPAD"]
# Out:
# 10588

# %% [markdown]
# Since the datasets are combined, we have to derive the original split sizes:
#
# - Original test set size = 126
# - Validation Set Size = 153

# %%
test_proportion = (126*0.2)/215
validation_proportion = (153*0.2)/215

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size=test_proportion, random_state=1)

# %% [markdown]
# ### 6: Bidirectional LSTM Model

# %%
from tensorflow.keras.layers import Input, Embedding, SpatialDropout1D, Bidirectional, LSTM, TimeDistributed, Dense
from tensorflow.keras.models import Model

# Define input and parameters
input_word = Input(shape=(max_len,))

# Define Embedding layer with mask_value to ignore the padding values
model = Embedding(input_dim=num_words+1, output_dim=max_len, input_length=max_len, mask_zero=True)(input_word)

# Add SpatialDropout1D
model = SpatialDropout1D(0.1)(model)

# Add Bidirectional LSTM
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)

# Add TimeDistributed Dense layer with softmax activation
out = TimeDistributed(Dense(num_tags, activation='softmax'))(model)

# Create the model
model = Model(inputs=input_word, outputs=out)

# Print model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            529450
#
#  spatial_dropout1d (Spatial  (None, 50, 50)            0
#  Dropout1D)
#
#  bidirectional (Bidirection  (None, 50, 200)           120800
#  al)
#
#  time_distributed (TimeDist  (None, 50, 5)             1005
#  ributed)
#
# =================================================================
# Total params: 651255 (2.48 MB)
# Trainable params: 651255 (2.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## 7: Training and Evaluation (Base Model)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',patience=2,verbose=0,mode='max',restore_best_weights=False)
callbacks = [PlotLossesCallback(),early_stopping]

history = model.fit(
    x_train,np.array(y_train),
    validation_split = validation_proportion,
    batch_size = 64,
    epochs = 5,
    verbose = 1,
    callbacks=callbacks
)
# Out:
# accuracy
# 	training         	 (min:    0.775, max:    0.875, cur:    0.875)
# 	validation       	 (min:    0.836, max:    0.869, cur:    0.869)
# Loss
# 	training         	 (min:    0.471, max:    1.428, cur:    0.471)
# 	validation       	 (min:    0.496, max:    0.949, cur:    0.496)
# 13/13 [==============================] - 3s 271ms/step - loss: 0.4710 - accuracy: 0.8749 - val_loss: 0.4956 - val_accuracy: 0.8686

# %% [markdown]
# padding value * test set size = number of predictions

# %% [markdown]
# Evaluate The Model

# %%
class_mapping = {0:'PAD', 1: 'B-O', 2: 'B-AC', 3: 'B-LF', 4: 'I-LF'}

evaluate_model(model, x_test, y_test, class_mapping, plot_title='Confusion Matrix', plot_size=(8, 8))
# Out:
# 4/4 [==============================] - 1s 55ms/step
# Class	Precision	Recall	F1 Score
# -----------------------------------
# B-O	0.8258	0.9963	0.9031
# B-AC	0.0000	0.0000	0.0000
# B-LF	0.0000	0.0000	0.0000
# I-LF	0.0000	0.0000	0.0000
#
# Weighted F1 score: 0.7461
# Macro F1 score: 0.1806
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Observe random predictions and their true labels for further error analysis.

# %%
tags = ['PAD','B-O', 'B-AC', 'B-LF', 'I-LF']
show_random_example(model, x_test, y_test, words, tags, random_state=1)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Word           True 	 Pred
#
# ------------------------------
# Ischaemia      B-O  	B-O
# -              B-O  	B-O
# reperfusion    B-O  	B-O
# injury         B-O  	B-O
# in             B-O  	B-O
# kidney         B-O  	B-O
# transplantationB-O  	B-O
# leads          B-O  	B-O
# to             B-O  	B-O
# delayed        B-LF 	B-O
# graft          I-LF 	B-O
# function       I-LF 	B-O
# (              B-O  	B-O
# DGF            B-AC 	B-O
# )              B-O  	B-O
# ,              B-O  	B-O
# which          B-O  	B-O
# is             B-O  	B-O
# associated     B-O  	B-O
# with           B-O  	B-O
# reduced        B-O  	B-O
# long           B-O  	B-O
# term           B-O  	B-O
# graft          B-O  	B-O
# function       B-O  	B-O
# .              B-O  	B-O
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
# ENDPAD         PAD  	PAD
